# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### Read the dataset to python environment.

# %%
df= pd.read_excel('G:\my trials\iris.xls')
df.head()
s
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ###### Display the columns in the dataset.

# %%
print(df.columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ###### Calculate the mean of each column of the dataset.

# %%
df['SL'].mean()
# Out:
# 5.843333333333335

# %%
df['SW'].mean()
# Out:
# 3.0540000000000007

# %%
df['PL'].mean()
# Out:
# 3.7586666666666693

# %%
df['PW'].mean()
# Out:
# 1.1986666666666672

# %% [markdown]
# ###### Check for the null values present in the dataset.

# %%
print(df.isnull().sum())
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ###### Perform meaningful visualizations using the dataset

# %%
plt.boxplot(df["SL"])
plt.xlabel("SL")
plt.title("Boxplot of SL",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Boxplot of SL')

# %%
sns.stripplot(x='SL',y='Classification',data=df)
sns.swarmplot(x='SL',y='Classification',data=df)
# Out:
# <AxesSubplot:xlabel='SL', ylabel='Classification'>

# %%
plt.figure(figsize=(6,16))
plt.subplot(4,1,1)
plt.scatter(df['SL'],df["Classification"],c="red")
plt.title("Scatterplot of SL Vs Classification ",fontsize=8)
plt.xlabel('SL')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
plt.grid()
plt.subplot(4,1,2)
plt.scatter(df['SW'],df["Classification"],c="blue")
plt.title("Scatterplot of SW Vs Classification",fontsize=8)
plt.xlabel('SW')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
plt.grid()
plt.subplot(4,1,3)
plt.scatter(df['PL'],df["Classification"],c="orange")
plt.title("Scatterplot of PL Vs Classification",fontsize=8)
plt.xlabel('PL')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
plt.grid()
plt.subplot(4,1,4)
plt.scatter(df['PW'],df["Classification"],c="green")
plt.title("Scatterplot of PW Vs Classification",fontsize=8)
plt.xlabel('PW')
plt.ylabel('Frequency')
plt.xticks()
plt.yticks()
plt.grid()
